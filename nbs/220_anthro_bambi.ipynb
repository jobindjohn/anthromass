# %% [markdown]
# # Model Made Using Bambi
# ## formula = weight + stature + Gender

# %%
import pandas as pd
import bambi as bmb
from anthromass.anthro_module import *

# %% [markdown]
# Here the models are made and fitted with the function "fit_model" which can be found in 201_anthropometry.ipynb. The formula can be changed and kindofmodel is want we decided to name these models, this can therefore also be changed when using a different formula.

# %%
variables = measurement_names()
kindofmodel = 'bambi'
formula = "weightkg + stature + Gender"
for var in variables:
    model = fit_model(var,formula)
    make_pickle(model, kindofmodel, var)
# Out:
# Initializing NUTS using adapt_diag...
# Sequential sampling (4 chains in 1 job)
# NUTS: [sigma, Intercept, weightkg, stature, Gender]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 2_000 tune and 2_000 draw iterations (8_000 + 8_000 draws total) took 22 seconds.
# Initializing NUTS using adapt_diag...
# Sequential sampling (4 chains in 1 job)
# NUTS: [sigma, Intercept, weightkg, stature, Gender]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 2_000 tune and 2_000 draw iterations (8_000 + 8_000 draws total) took 35 seconds.
