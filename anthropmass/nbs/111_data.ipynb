# %%
import pandas as pd

# %%
ansur = pd.read_csv('../data/processed/ANSURIImalefemale.csv')

# %%
ansur['weightkg'] = ansur['weightkg']-ansur['weightkg'].mean()
ansur['stature'] = ansur['stature']-ansur['stature'].mean()

# %%
ansur.to_csv('../data/processed/ANSURIImalefemaleminusmeans.csv', index=False)
