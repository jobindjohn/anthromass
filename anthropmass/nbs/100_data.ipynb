# %% [markdown]
# ## Export

# %%
#| default_exp data_module

# %%
#| export
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Normailze
# One function for normalizing, and then one function for normalizing multiple measurements.

# %%
#| export
def normalize(data:dict, measurement:str):
    ansur=pd.read_csv('../data/processed/ANSURIImalefemale.csv')
    avg_m = ansur[measurement].mean()
    std_m = ansur[measurement].std()
    data[measurement] = (data[measurement] - avg_m) / std_m
    return data

# %%
#| export
def normalize_all(data, measurement:list):
    for m in measurement:
        data = normalize(data, m)
    return data

# %%
ansur=pd.read_csv('../data/processed/ANSURIImalefemale.csv')
normalized = normalize_all(ansur, ['weightkg', 'stature'])
normalized.to_csv('../data/processed/ANSURIInormalized.csv', index=False)

# %% [markdown]
# ### Train and test data

# %%
#| export
def make_train_test(data, test_size:float):
    train, test = train_test_split(data, test_size=test_size, shuffle=True, random_state=42)
    return train, test

# %%
train, test = make_train_test(normalized,0.2)
train.to_csv('../data/processed/ANSURIInormalizedtrain.csv', index=False)
test.to_csv('../data/processed/ANSURIInormalizedtest.csv', index=False)

# %%
ansur=pd.read_csv('../data/processed/ANSURIImalefemale.csv')
train, test = make_train_test(ansur, 0.2)
train.to_csv('../data/processed/ANSURIItrain.csv', index=False)
test.to_csv('../data/processed/ANSURIItest.csv', index=False)
test
# Out:
#       subjectid  abdominalextensiondepthsitting  acromialheight  \
# 2764      26671                             237            1467
# 2722      26193                             211            1561
# 5388      25698                             261            1419
# 4443      16567                             251            1481
# 3133      27489                             212            1500
# ...         ...                             ...             ...
# 4500      17463                             220            1358
# 2873      26898                             232            1352
# 3838      28953                             213            1398
# 1789      16418                             358            1453
# 861       13949                             238            1459
#
#       acromionradialelength  anklecircumference  axillaheight  \
# 2764                    334                 255          1364
# 2722                    355                 230          1448
# 5388                    332                 232          1318
# 4443                    310                 234          1375
# 3133                    355                 231          1378
# ...                     ...                 ...           ...
# 4500                    294                 218          1260
# 2873                    319                 207          1251
# 3838                    334                 225          1293
# 1789                    338                 260          1334
# 861                     325                 225          1350
#
#       balloffootcircumference  balloffootlength  biacromialbreadth  \
# 2764                      293               225                454
# 2722                      248               221                428
# 5388                      232               195                387
# 4443                      231               199                390
# 3133                      260               217                418
# ...                       ...               ...                ...
# 4500                      227               166                354
# 2873                      229               197                412
# 3838                      252               215                452
# 1789                      277               191                457
# 861                       230               185                418
#
#       bicepscircumferenceflexed  ...                  Branch  PrimaryMOS  \
# 2764                        355  ...  Combat Service Support         25S
# 2722                        333  ...  Combat Service Support         25L
# 5388                        347  ...  Combat Service Support         25B
# 4443                        325  ...  Combat Service Support         91J
# 3133                        365  ...  Combat Service Support         35D
# ...                         ...  ...                     ...         ...
# 4500                        307  ...          Combat Support         46Q
# 2873                        340  ...          Combat Support         25B
# 3838                        443  ...  Combat Service Support         35G
# 1789                        420  ...  Combat Service Support         31B
# 861                         364  ...             Combat Arms         11Z
#
#       SubjectsBirthLocation  SubjectNumericRace  Ethnicity  DODRace  Age  \
# 2764             California                  31    Mexican        1   25
# 2722         North Carolina                   2        NaN        2   22
# 5388              Minnesota                   1        NaN        1   19
# 4443               Michigan                   1        NaN        1   33
# 3133               New York                   1        NaN        1   27
# ...                     ...                 ...        ...      ...  ...
# 4500               Michigan                   1        NaN        1   29
# 2873         North Carolina                   1        NaN        1   33
# 3838             California                   2        NaN        2   40
# 1789               Oklahoma                   1        NaN        1   26
# 861          North Carolina                   1        NaN        1   44
#
#       Heightin  Weightlbs            WritingPreference
# 2764        73        187                   Right hand
# 2722        74        173                   Right hand
# 5388        68        165                   Right hand
# 4443        72        178  Either hand (No preference)
# 3133        73        184                    Left hand
# ...        ...        ...                          ...
# 4500        66        165                   Right hand
# 2873        67        160                   Right hand
# 3838        69        195                   Right hand
# 1789        70        250                    Left hand
# 861         71        175                   Right hand
#
# [1214 rows x 108 columns]
