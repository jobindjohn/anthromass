# %%
import pandas as pd
import bambi as bmb
from anthropmass.anthro_module import *

# %%
train=pd.read_csv('../data/processed/ANSURIIminusmeanstrain.csv')

# %%
y_train=train.iloc[:,1:94].drop('weightkg',axis=1).drop('stature',axis=1)
#variables = y_train.columns[0:3]
variables = ["neckcircumference"]

# %%
kindofmodel = 'bambi_c'
formula='0 + C(Gender) + Component + weightkg + stature'
for var in variables:
    fitted = fit_model(var, formula)
    make_pickle(fitted, kindofmodel, var)
# Out:
# Initializing NUTS using adapt_diag...
# Sequential sampling (4 chains in 1 job)
# NUTS: [sigma, C(Gender), Component, weightkg, stature]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 2_000 tune and 2_000 draw iterations (8_000 + 8_000 draws total) took 26 seconds.
